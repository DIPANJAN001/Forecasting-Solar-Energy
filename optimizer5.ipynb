# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Forecasting-Solar-Energy/blob/master/optimizer5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install Boruta
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import concatenate
from keras import Model
from keras.layers import Input
from keras.layers import Bidirectional
from keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model
from keras.layers import Input
from sklearn.decomposition import PCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.1.0)
# Installing collected packages: Boruta
# Successfully installed Boruta-0.3

# %%
def lstm_data_transform(x_data, y_data, num_steps):
    """ Changes data to the format for LSTM training 
for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
df=pd.read_excel("/content/pv_04.xlsx")
weather_input1=df.drop('power_normed',axis=1)
weather_input=weather_input1.drop('time_idx',axis=1)
solpow=df['power_normed']

# %%
rfc = RandomForestRegressor(random_state=1, n_estimators=1000, max_depth=5)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(weather_input), np.array(solpow))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	9
# Tentative: 	17
# Rejected: 	23
# Iteration: 	9 / 100
# Confirmed: 	9
# Tentative: 	17
# Rejected: 	23
# Iteration: 	10 / 100
# Confirmed: 	9
# Tentative: 	17
# Rejected: 	23
# Iteration: 	11 / 100
# Confirmed: 	9
# Tentative: 	17
# Rejected: 	23
# Iteration: 	12 / 100
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	23
# Iteration: 	13 / 100
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	23
# Iteration: 	14 / 100
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	23
# Iteration: 	15 / 100
# Confirmed: 	10
# Tentative: 	16
# Rejected: 	23
# Iteration: 	16 / 100
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	23
# Iteration: 	17 / 100
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	23
# Iteration: 	18 / 100
# Confirmed: 	11
# Tentative: 	15
# Rejected: 	23
# Iteration: 	19 / 100
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	23
# Iteration: 	20 / 100
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	23
# Iteration: 	21 / 100
# Confirmed: 	12
# Tentative: 	14
# Rejected: 	23
# Iteration: 	22 / 100
# Confirmed: 	14
# Tentative: 	12
# Rejected: 	23
# Iteration: 	23 / 100
# Confirmed: 	14
# Tentative: 	12
# Rejected: 	23
# Iteration: 	24 / 100
# Confirmed: 	14
# Tentative: 	12
# Rejected: 	23
# Iteration: 	25 / 100
# Confirmed: 	14
# Tentative: 	12
# Rejected: 	23
# Iteration: 	26 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	27 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	28 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	29 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	30 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	31 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	32 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	33 / 100
# Confirmed: 	15
# Tentative: 	10
# Rejected: 	24
# Iteration: 	34 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	35 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	36 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	37 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	38 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	39 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	40 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	41 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	42 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	43 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	44 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	45 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	46 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	47 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	48 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	49 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	50 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	51 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	52 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	53 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	54 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	55 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	56 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	57 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	58 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	59 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	60 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	61 / 100
# Confirmed: 	16
# Tentative: 	9
# Rejected: 	24
# Iteration: 	62 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	63 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	64 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	65 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	66 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	67 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	68 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	69 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	70 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	71 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	72 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	73 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	74 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	75 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	76 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	88 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	89 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	90 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	91 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	92 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	93 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	94 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	95 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	96 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	97 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	98 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
# Iteration: 	99 / 100
# Confirmed: 	18
# Tentative: 	7
# Rejected: 	24
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	18
# Tentative: 	2
# Rejected: 	24
# BorutaPy(estimator=RandomForestRegressor(max_depth=5, n_estimators=141,
#                                          random_state=RandomState(MT19937) at 0x7F2E780E6540),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7F2E780E6540, verbose=2)

# %%
X_important_train = boruta_selector.transform(np.array(weather_input))
num_steps = 2
# training set
(x_transformed_train,
 y_transformed_train) = lstm_data_transform(X_important_train,solpow , num_steps=num_steps)
assert x_transformed_train.shape[0] == y_transformed_train.shape[0]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_transformed_train,y_transformed_train,test_size=0.33, random_state=42,shuffle=False)
#X_train_,X_val,y_train_,y_val=train_test_split(X_train,y_train,test_size=0.2, random_state=42,shuffle=False)
inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))

# %%
inputs1
# Out:
# <KerasTensor: shape=(None, 2, 18) dtype=float32 (created by layer 'input_1')>

# %%
from keras import optimizers

# %%
from keras.optimizers import Adam
import numpy as np

class SPANDAN(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + 2*distance for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters*s
            params_2 = [b - 2*distance for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
from keras.layers import Bidirectional

# %%
def define_model():



  '''fe1_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = Bidirectional(LSTM(24, activation='relu',return_sequences = True))(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=Bidirectional(LSTM(30, activation='relu'))(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)'''



  fe2_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = Bidirectional(LSTM(60, activation='relu',return_sequences = True))(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=Bidirectional(LSTM(4, activation='relu'))(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =Bidirectional(LSTM(104, activation='relu',return_sequences = True))(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = Bidirectional(LSTM(96, activation='relu',return_sequences = True))(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=Bidirectional(LSTM(8, activation='relu'))(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([ out3_1, out2_1])
  #merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer =SPANDAN(),loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 75,validation_split=0.2,batch_size =32)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/75
# 102/102 [==============================] - 21s 58ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 2/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 3/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 4/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 5/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 6/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 7/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 8/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 9/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 10/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 11/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 12/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 13/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 14/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 15/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 16/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 17/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 18/75
# 102/102 [==============================] - 4s 39ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 19/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 20/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 21/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 22/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 23/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 24/75
# 102/102 [==============================] - 6s 57ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 25/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 26/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 27/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 28/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 29/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 30/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 31/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 32/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 33/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 34/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 35/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 36/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 37/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 38/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 39/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 40/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 41/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 42/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 43/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 44/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 45/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 46/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 47/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 48/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 49/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 50/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 51/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 52/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 53/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 54/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 55/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 56/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 57/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 58/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 59/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 60/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 61/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 62/75
# 102/102 [==============================] - 4s 38ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 63/75
# 102/102 [==============================] - 4s 39ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 64/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 65/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 66/75
# 102/102 [==============================] - 4s 40ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 67/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 68/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 69/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 70/75
# 102/102 [==============================] - 5s 48ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 71/75
# 102/102 [==============================] - 5s 50ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 72/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 73/75
# 102/102 [==============================] - 4s 42ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 74/75
# 102/102 [==============================] - 4s 41ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 75/75
# 102/102 [==============================] - 4s 43ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0016 - val_mse: 0.0016
# 63/63 [==============================] - 2s 11ms/step
# 0.05293536978876061

# %%
def define_model():


  # firs
  fe1_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = Bidirectional(LSTM(24, activation='relu',return_sequences = True))(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=Bidirectional(LSTM(30, activation='relu'))(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = Bidirectional(LSTM(60, activation='relu',return_sequences = True))(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=Bidirectional(LSTM(4, activation='relu'))(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =Bidirectional(LSTM(104, activation='relu',return_sequences = True))(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = Bidirectional(LSTM(96, activation='relu',return_sequences = True))(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=Bidirectional(LSTM(8, activation='relu'))(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=SPANDAN(),loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 80,validation_split=0.2,batch_size =128)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/80
# 26/26 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0218
# KeyboardInterrupt
