# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Forecasting-Solar-Energy/blob/master/bestresult05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install Boruta
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import concatenate
from keras import Model
from keras.layers import Input
from keras.layers import Bidirectional
from keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model
from keras.layers import Input
from sklearn.decomposition import PCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Boruta in /usr/local/lib/python3.8/dist-packages (0.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.0.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.7.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.1.0)

# %%
def lstm_data_transform(x_data, y_data, num_steps):
    """ Changes data to the format for LSTM training 
for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
df=pd.read_excel("/content/pv_05.xlsx")
weather_input1=df.drop('power_normed',axis=1)
weather_input=weather_input1.drop('time_idx',axis=1)
solpow=df['power_normed']

# %%
rfc = RandomForestRegressor(random_state=1, n_estimators=1000, max_depth=7)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(weather_input), np.array(solpow))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	34
# Iteration: 	9 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	34
# Iteration: 	10 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	34
# Iteration: 	11 / 100
# Confirmed: 	11
# Tentative: 	4
# Rejected: 	34
# Iteration: 	12 / 100
# Confirmed: 	11
# Tentative: 	2
# Rejected: 	36
# Iteration: 	13 / 100
# Confirmed: 	11
# Tentative: 	2
# Rejected: 	36
# Iteration: 	14 / 100
# Confirmed: 	11
# Tentative: 	2
# Rejected: 	36
# Iteration: 	15 / 100
# Confirmed: 	11
# Tentative: 	2
# Rejected: 	36
# Iteration: 	16 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	17 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	18 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	19 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	20 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	21 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	22 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	23 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	24 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	25 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	26 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	27 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	28 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	29 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	30 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	31 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	32 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	33 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	34 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	35 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	36 / 100
# Confirmed: 	12
# Tentative: 	1
# Rejected: 	36
# Iteration: 	37 / 100
# Confirmed: 	13
# Tentative: 	0
# Rejected: 	36
#
#
# BorutaPy finished running.
#
# Iteration: 	38 / 100
# Confirmed: 	13
# Tentative: 	0
# Rejected: 	36
# BorutaPy(estimator=RandomForestRegressor(max_depth=7, n_estimators=72,
#                                          random_state=RandomState(MT19937) at 0x7FEEB84C2740),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7FEEB84C2740, verbose=2)

# %%
X_important_train = boruta_selector.transform(np.array(weather_input))
num_steps = 3
# training set
(x_transformed_train,
 y_transformed_train) = lstm_data_transform(X_important_train,solpow , num_steps=num_steps)
assert x_transformed_train.shape[0] == y_transformed_train.shape[0]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_transformed_train,y_transformed_train,test_size=0.25, random_state=42,shuffle=False)
#X_train_,X_val,y_train_,y_val=train_test_split(X_train,y_train,test_size=0.2, random_state=42,shuffle=False)
inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))

# %%
inputs1
# Out:
# <KerasTensor: shape=(None, 3, 13) dtype=float32 (created by layer 'input_2')>

# %%
from keras import optimizers

# %%
opt=optimizers.Adam(learning_rate=0.003)

# %%
from keras.layers import Bidirectional

# %%
from keras import optimizers

class CustomAdam(optimizers.Adam):
    def __init__(self, new_idea_param=0.1, *args, **kwargs):
        self.new_idea_param = new_idea_param
        super(CustomAdam, self).__init__(*args, **kwargs)

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        lr = self.lr
        if self.initial_decay > 0:
            lr *= (1. / (1. + self.decay * K.cast(self.iterations, K.dtype(self.decay))))

        t = K.cast(self.iterations, K.floatx()) + 1
        lr_t = lr * (K.sqrt(1. - K.pow(self.beta_2, t)) / (1. - K.pow(self.beta_1, t)))

        new_idea_t = self.new_idea_param * (K.sqrt(1. - K.pow(self.beta_2, t)) / (1. - K.pow(self.beta_1, t)))

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        self.weights = [self.iterations] + ms + vs

        for p, g, m, v in zip(params, grads, ms, vs):
            m_t = (self.beta_1 * m) + (1. - self.beta_1) * g
            v_t = (self.beta_2 * v) + (1. - self.beta_2) * K.square(g)
            p_t = p - lr_t * m_t / (K.sqrt(v_t) + self.epsilon) - new_idea_t * g

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            self.updates.append(K.update(p, p_t))
        return self.updates

# %%
from keras import optimizers

class GradientAdam(optimizers.Adam):
    def __init__(self, gradient_param=0.1, *args, **kwargs):
        self.gradient_param = gradient_param
        super(GradientAdam, self).__init__(*args, **kwargs)

    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [K.update_add(self.iterations, 1)]

        lr = self.lr
        if self.initial_decay > 0:
            lr *= (1. / (1. + self.decay * K.cast(self.iterations, K.dtype(self.decay))))

        t = K.cast(self.iterations, K.floatx()) + 1
        lr_t = lr * (K.sqrt(1. - K.pow(self.beta_2, t)) / (1. - K.pow(self.beta_1, t)))

        gradient_t = self.gradient_param * grads

        ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
        self.weights = [self.iterations] + ms + vs

        for p, g, m, v, g_t in zip(params, grads, ms, vs, gradient_t):
            m_t = (self.beta_1 * m) + (1. - self.beta_1) * g
            v_t = (self.beta_2 * v) + (1. - self.beta_2) * K.square(g)
            p_t = p - lr_t * m_t / (K.sqrt(v_t) + self.epsilon) + g_t

            self.updates.append(K.update(m, m_t))
            self.updates.append(K.update(v, v_t))
            self.updates.append(K.update(p, p_t))
        return self.updates

# %%
import tensorflow as tf

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.python.ops import math_ops

class HalvAdam(Adam):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.prev_gradients = None

    @tf.function
    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = [math_ops.cast(x, "float32") for x in grads]

        if self.prev_gradients is not None:
            for i in range(len(grads)):
                if (grads[i] * self.prev_gradients[i] < 0):
                    self.updates[i] = self.updates[i] / 2

        self.prev_gradients = grads
        return self.updates

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.python.ops import math_ops

class AdaptiveAdam(Adam):
    def __init__(self, *args, factor=0.5, patience=5, **kwargs):
        super().__init__(*args, **kwargs)
        self.factor = factor
        self.patience = patience
        self.wait = 0
        self.best_loss = float('inf')
        self.best_weights = None

    @tf.function
    def get_updates(self, loss, params):
        current_loss = loss()
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = params
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.wait = 0
                self.lr = self.lr * self.factor
                params = self.best_weights
        grads = self.get_gradients(loss, params)
        self.updates = [math_ops.cast(g, "float32") for g in grads]
        return self.updates

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.python.ops import math_ops

class MomentumAdam(Adam):
    def __init__(self, *args, momentum=0.9, **kwargs):
        super().__init__(*args, **kwargs)
        self.momentum = momentum
        self.velocities = [tf.Variable(tf.zeros_like(p), trainable=False) for p in self.weights]

    @tf.function
    def get_updates(self, loss, params):
        grads = self.get_gradients(loss, params)
        self.updates = []
        for p, g, v in zip(params, grads, self.velocities):
            v_t = self.momentum * v - self.lr * g
            p_t = p + v_t
            self.updates.append(p_t)
            self.updates.append(v_t)
        return self.updates

# %%
from keras import backend as K

# %%
import tensorflow as tf

# %%
def define_model():


  fe2_0 = Bidirectional(LSTM(256, activation='LeakyReLU',return_sequences = True))(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = Bidirectional(LSTM(64, activation='LeakyReLU',return_sequences = True))(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=Bidirectional(LSTM(4, activation='LeakyReLU'))(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =Bidirectional(LSTM(128, activation='LeakyReLU',return_sequences = True))(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = Bidirectional(LSTM(96, activation='LeakyReLU',return_sequences = True))(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=Bidirectional(LSTM(8, activation='LeakyReLU'))(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([out2_1, out3_1])
  #merged3 = concatenate([out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  
 
  return model
mdl=define_model()

# %%
loss=[]

# %%
from keras.models import clone_model

# %%
from keras.optimizers import Adam

# %%
from keras.callbacks import ModelCheckpoint

# %%
def GlobalMinimaSearch(weights):
  if len(loss)>9:
   return
  
  initial_weights =weights
  model=clone_model(mdl)
  model.set_weights(weights)
  model.compile(optimizer=HalvAdam(learning_rate=0.003), loss='mean_squared_error')
  model.fit(X_train, y_train, epochs=120, batch_size=128)
  y= model.predict(X_test)
  loss.append(np.sqrt(mean_squared_error(y,y_test)))
  best_weights= model.get_weights()
  

     

  params_1 =[final_weight + (final_weight - initial_weight) for initial_weight, final_weight in zip(initial_weights, best_weights)]
  #GlobalMinimaSearch(params_1)


  params_2 =[final_weight - (final_weight - initial_weight) for initial_weight, final_weight in zip(initial_weights, best_weights)]
  GlobalMinimaSearch(params_2)

# %%
GlobalMinimaSearch(mdl.get_weights())
# Out:
# Epoch 1/120
# 37/37 [==============================] - 28s 144ms/step - loss: 0.0093
# Epoch 2/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0044
# Epoch 3/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0042
# Epoch 4/120
# 37/37 [==============================] - 6s 176ms/step - loss: 0.0038
# Epoch 5/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0036
# Epoch 6/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0037
# Epoch 7/120
# 37/37 [==============================] - 6s 146ms/step - loss: 0.0036
# Epoch 8/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0033
# Epoch 9/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0033
# Epoch 10/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0032
# Epoch 11/120
# 37/37 [==============================] - 9s 237ms/step - loss: 0.0031
# Epoch 12/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0032
# Epoch 13/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0031
# Epoch 14/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0033
# Epoch 15/120
# 37/37 [==============================] - 7s 187ms/step - loss: 0.0029
# Epoch 16/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0029
# Epoch 17/120
# 37/37 [==============================] - 6s 177ms/step - loss: 0.0031
# Epoch 18/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0032
# Epoch 19/120
# 37/37 [==============================] - 7s 192ms/step - loss: 0.0031
# Epoch 20/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0029
# Epoch 21/120
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0030
# Epoch 22/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0030
# Epoch 23/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0030
# Epoch 24/120
# 37/37 [==============================] - 7s 193ms/step - loss: 0.0029
# Epoch 25/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0029
# Epoch 26/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0030
# Epoch 27/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0029
# Epoch 28/120
# 37/37 [==============================] - 6s 174ms/step - loss: 0.0028
# Epoch 29/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0029
# Epoch 30/120
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0028
# Epoch 31/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0029
# Epoch 32/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0028
# Epoch 33/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0027
# Epoch 34/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0028
# Epoch 35/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0028
# Epoch 36/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0029
# Epoch 37/120
# 37/37 [==============================] - 7s 174ms/step - loss: 0.0027
# Epoch 38/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0027
# Epoch 39/120
# 37/37 [==============================] - 6s 176ms/step - loss: 0.0028
# Epoch 40/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0028
# Epoch 41/120
# 37/37 [==============================] - 6s 176ms/step - loss: 0.0027
# Epoch 42/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0027
# Epoch 43/120
# 37/37 [==============================] - 6s 173ms/step - loss: 0.0027
# Epoch 44/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0028
# Epoch 45/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0028
# Epoch 46/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0027
# Epoch 47/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0027
# Epoch 48/120
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0027
# Epoch 49/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0027
# Epoch 50/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0026
# Epoch 51/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0026
# Epoch 52/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0026
# Epoch 53/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0026
# Epoch 54/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0026
# Epoch 55/120
# 37/37 [==============================] - 6s 146ms/step - loss: 0.0029
# Epoch 56/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0027
# Epoch 57/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0027
# Epoch 58/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0027
# Epoch 59/120
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0026
# Epoch 60/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0026
# Epoch 61/120
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0026
# Epoch 62/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0026
# Epoch 63/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0027
# Epoch 64/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0026
# Epoch 65/120
# 37/37 [==============================] - 8s 210ms/step - loss: 0.0026
# Epoch 66/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0026
# Epoch 67/120
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0027
# Epoch 68/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0026
# Epoch 69/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0026
# Epoch 70/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0026
# Epoch 71/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0025
# Epoch 72/120
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0025
# Epoch 73/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 74/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0028
# Epoch 75/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0025
# Epoch 76/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0026
# Epoch 77/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0026
# Epoch 78/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0026
# Epoch 79/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0025
# Epoch 80/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0028
# Epoch 81/120
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0026
# Epoch 82/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0025
# Epoch 83/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0025
# Epoch 84/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0025
# Epoch 85/120
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0026
# Epoch 86/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0026
# Epoch 87/120
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0025
# Epoch 88/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 89/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 90/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0025
# Epoch 91/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0026
# Epoch 92/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0024
# Epoch 93/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0024
# Epoch 94/120
# 37/37 [==============================] - 7s 182ms/step - loss: 0.0025
# Epoch 95/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0026
# Epoch 96/120
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0025
# Epoch 97/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0024
# Epoch 98/120
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0025
# Epoch 99/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 100/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0025
# Epoch 101/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0025
# Epoch 102/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0025
# Epoch 103/120
# 37/37 [==============================] - 7s 175ms/step - loss: 0.0025
# Epoch 104/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0024
# Epoch 105/120
# 37/37 [==============================] - 8s 216ms/step - loss: 0.0024
# Epoch 106/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0023
# Epoch 107/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0024
# Epoch 108/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0026
# Epoch 109/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0025
# Epoch 110/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 111/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0026
# Epoch 112/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0024
# Epoch 113/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0023
# Epoch 114/120
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0024
# Epoch 115/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0024
# Epoch 116/120
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0024
# Epoch 117/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0024
# Epoch 118/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0025
# Epoch 119/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0024
# Epoch 120/120
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0026
# 50/50 [==============================] - 3s 23ms/step
# Epoch 1/120
# 37/37 [==============================] - 22s 181ms/step - loss: 0.0090
# Epoch 2/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0044
# Epoch 3/120
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0040
# Epoch 4/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0038
# Epoch 5/120
# 37/37 [==============================] - 7s 182ms/step - loss: 0.0039
# Epoch 6/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0038
# Epoch 7/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0034
# Epoch 8/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0033
# Epoch 9/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0034
# Epoch 10/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0031
# Epoch 11/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0031
# Epoch 12/120
# 37/37 [==============================] - 7s 178ms/step - loss: 0.0032
# Epoch 13/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0032
# Epoch 14/120
# 37/37 [==============================] - 7s 177ms/step - loss: 0.0031
# Epoch 15/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0030
# Epoch 16/120
# 37/37 [==============================] - 6s 175ms/step - loss: 0.0030
# Epoch 17/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0032
# Epoch 18/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0032
# Epoch 19/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0029
# Epoch 20/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0029
# Epoch 21/120
# 37/37 [==============================] - 6s 173ms/step - loss: 0.0031
# Epoch 22/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0030
# Epoch 23/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0029
# Epoch 24/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0028
# Epoch 25/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0029
# Epoch 26/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0030
# Epoch 27/120
# 37/37 [==============================] - 6s 164ms/step - loss: 0.0028
# Epoch 28/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0028
# Epoch 29/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0027
# Epoch 30/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0028
# Epoch 31/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0028
# Epoch 32/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0029
# Epoch 33/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0028
# Epoch 34/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0029
# Epoch 35/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0028
# Epoch 36/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0028
# Epoch 37/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0028
# Epoch 38/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0027
# Epoch 39/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0028
# Epoch 40/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0028
# Epoch 41/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0027
# Epoch 42/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0028
# Epoch 43/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0027
# Epoch 44/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028
# Epoch 45/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0027
# Epoch 46/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0027
# Epoch 47/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0027
# Epoch 48/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0027
# Epoch 49/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0027
# Epoch 50/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0026
# Epoch 51/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0029
# Epoch 52/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0027
# Epoch 53/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0027
# Epoch 54/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0026
# Epoch 55/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0027
# Epoch 56/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0027
# Epoch 57/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0026
# Epoch 58/120
# 37/37 [==============================] - 6s 173ms/step - loss: 0.0026
# Epoch 59/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0027
# Epoch 60/120
# 37/37 [==============================] - 6s 176ms/step - loss: 0.0026
# Epoch 61/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0025
# Epoch 62/120
# 37/37 [==============================] - 7s 202ms/step - loss: 0.0025
# Epoch 63/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0027
# Epoch 64/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0028
# Epoch 65/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0027
# Epoch 66/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0026
# Epoch 67/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0026
# Epoch 68/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0027
# Epoch 69/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0027
# Epoch 70/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0027
# Epoch 71/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0026
# Epoch 72/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0026
# Epoch 74/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0026
# Epoch 75/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0025
# Epoch 76/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0026
# Epoch 77/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 78/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0025
# Epoch 79/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0025
# Epoch 80/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028
# Epoch 81/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0027
# Epoch 82/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0025
# Epoch 83/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0027
# Epoch 84/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0025
# Epoch 85/120
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0025
# Epoch 86/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0025
# Epoch 87/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0025
# Epoch 88/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0024
# Epoch 89/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0026
# Epoch 90/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0026
# Epoch 91/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0025
# Epoch 92/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 93/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0025
# Epoch 94/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0025
# Epoch 95/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0025
# Epoch 96/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0025
# Epoch 97/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0025
# Epoch 98/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0027
# Epoch 99/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0026
# Epoch 100/120
# 37/37 [==============================] - 6s 146ms/step - loss: 0.0024
# Epoch 101/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0024
# Epoch 102/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0025
# Epoch 103/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0025
# Epoch 104/120
# 37/37 [==============================] - 7s 193ms/step - loss: 0.0025
# Epoch 105/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0024
# Epoch 106/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0025
# Epoch 107/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0024
# Epoch 108/120
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0024
# Epoch 109/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0024
# Epoch 110/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0023
# Epoch 111/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0025
# Epoch 112/120
# 37/37 [==============================] - 6s 170ms/step - loss: 0.0025
# Epoch 113/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0024
# Epoch 114/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0023
# Epoch 115/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0026
# Epoch 116/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0024
# Epoch 117/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0023
# Epoch 118/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0023
# Epoch 119/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0024
# Epoch 120/120
# 37/37 [==============================] - 6s 167ms/step - loss: 0.0023
# 50/50 [==============================] - 3s 22ms/step
# Epoch 1/120
# 37/37 [==============================] - 20s 144ms/step - loss: 0.0093
# Epoch 2/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0045
# Epoch 3/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0040
# Epoch 4/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0037
# Epoch 5/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0037
# Epoch 6/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0036
# Epoch 7/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0036
# Epoch 8/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0034
# Epoch 9/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0032
# Epoch 10/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0032
# Epoch 11/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0031
# Epoch 12/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0031
# Epoch 13/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0032
# Epoch 14/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0034
# Epoch 15/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0034
# Epoch 16/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0031
# Epoch 17/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0031
# Epoch 18/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0032
# Epoch 19/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0030
# Epoch 20/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 21/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0029
# Epoch 22/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0031
# Epoch 23/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0030
# Epoch 24/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0029
# Epoch 25/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0029
# Epoch 26/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0029
# Epoch 27/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0029
# Epoch 28/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0029
# Epoch 29/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0029
# Epoch 30/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0029
# Epoch 31/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0029
# Epoch 32/120
# 37/37 [==============================] - 6s 148ms/step - loss: 0.0031
# Epoch 33/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0028
# Epoch 34/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0028
# Epoch 35/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0029
# Epoch 36/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0027
# Epoch 37/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0028
# Epoch 38/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0028
# Epoch 39/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 40/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0027
# Epoch 41/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0028
# Epoch 42/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0027
# Epoch 43/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0027
# Epoch 44/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0027
# Epoch 45/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0027
# Epoch 46/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0030
# Epoch 47/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0029
# Epoch 48/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 49/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0027
# Epoch 50/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0027
# Epoch 51/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0028
# Epoch 52/120
# 37/37 [==============================] - 6s 148ms/step - loss: 0.0027
# Epoch 53/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0027
# Epoch 54/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0026
# Epoch 55/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0028
# Epoch 56/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0027
# Epoch 57/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0027
# Epoch 58/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0026
# Epoch 59/120
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0026
# Epoch 60/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0026
# Epoch 61/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0027
# Epoch 62/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0026
# Epoch 63/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0027
# Epoch 64/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0028
# Epoch 65/120
# 37/37 [==============================] - 6s 147ms/step - loss: 0.0027
# Epoch 66/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0027
# Epoch 67/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0027
# Epoch 68/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0026
# Epoch 69/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0026
# Epoch 70/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0026
# Epoch 71/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0026
# Epoch 72/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 6s 165ms/step - loss: 0.0026
# Epoch 74/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 75/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 76/120
# 37/37 [==============================] - 6s 145ms/step - loss: 0.0025
# Epoch 77/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0026
# Epoch 78/120
# 37/37 [==============================] - 6s 172ms/step - loss: 0.0027
# Epoch 79/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0026
# Epoch 80/120
# 37/37 [==============================] - 6s 169ms/step - loss: 0.0026
# Epoch 81/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0025
# Epoch 82/120
# 37/37 [==============================] - 6s 164ms/step - loss: 0.0026
# Epoch 83/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0025
# Epoch 84/120
# 37/37 [==============================] - 6s 166ms/step - loss: 0.0025
# Epoch 85/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0026
# Epoch 86/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0026
# Epoch 87/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 88/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0026
# Epoch 89/120
# 37/37 [==============================] - 6s 148ms/step - loss: 0.0026
# Epoch 90/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0025
# Epoch 91/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0025
# Epoch 92/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0025
# Epoch 93/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0025
# Epoch 94/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# Epoch 95/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0025
# Epoch 96/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0025
# Epoch 97/120
# 37/37 [==============================] - 6s 161ms/step - loss: 0.0024
# Epoch 98/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# Epoch 99/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0024
# Epoch 100/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0025
# Epoch 101/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0024
# Epoch 102/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0025
# Epoch 103/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0026
# Epoch 104/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0025
# Epoch 105/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0023
# Epoch 106/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0024
# Epoch 107/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0025
# Epoch 108/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0026
# Epoch 109/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 110/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0024
# Epoch 111/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0026
# Epoch 112/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0024
# Epoch 113/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0024
# Epoch 114/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0025
# Epoch 115/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0023
# Epoch 116/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 117/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0025
# Epoch 118/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0024
# Epoch 119/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0024
# Epoch 120/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# 50/50 [==============================] - 3s 20ms/step
# Epoch 1/120
# 37/37 [==============================] - 20s 146ms/step - loss: 0.0103
# Epoch 2/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0044
# Epoch 3/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0038
# Epoch 4/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0038
# Epoch 5/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0038
# Epoch 6/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0036
# Epoch 7/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0034
# Epoch 8/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0034
# Epoch 9/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0033
# Epoch 10/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0035
# Epoch 11/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034
# Epoch 12/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0031
# Epoch 13/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0033
# Epoch 14/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0031
# Epoch 15/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0032
# Epoch 16/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0036
# Epoch 17/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0032
# Epoch 18/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 19/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0031
# Epoch 20/120
# 37/37 [==============================] - 7s 181ms/step - loss: 0.0031
# Epoch 21/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0030
# Epoch 22/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0029
# Epoch 23/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0031
# Epoch 24/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0029
# Epoch 25/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0029
# Epoch 26/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0030
# Epoch 27/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0029
# Epoch 28/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0029
# Epoch 29/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 30/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0028
# Epoch 31/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 32/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0029
# Epoch 33/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0030
# Epoch 34/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0028
# Epoch 35/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0029
# Epoch 36/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028
# Epoch 37/120
# 37/37 [==============================] - 5s 127ms/step - loss: 0.0029
# Epoch 38/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 39/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0027
# Epoch 40/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0028
# Epoch 41/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0027
# Epoch 42/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0028
# Epoch 43/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 44/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0028
# Epoch 45/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0028
# Epoch 46/120
# 37/37 [==============================] - 6s 149ms/step - loss: 0.0029
# Epoch 47/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0027
# Epoch 48/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0027
# Epoch 49/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 50/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 51/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0030
# Epoch 52/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0028
# Epoch 53/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0026
# Epoch 54/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0027
# Epoch 55/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0028
# Epoch 56/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 57/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0027
# Epoch 58/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 59/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0027
# Epoch 60/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0026
# Epoch 61/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0028
# Epoch 62/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0027
# Epoch 63/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0029
# Epoch 64/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0026
# Epoch 65/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 66/120
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0026
# Epoch 67/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0027
# Epoch 68/120
# 37/37 [==============================] - 5s 147ms/step - loss: 0.0026
# Epoch 69/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0026
# Epoch 70/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 71/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 72/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0026
# Epoch 74/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 75/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 76/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 77/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0027
# Epoch 78/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0026
# Epoch 79/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 80/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 81/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 82/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0025
# Epoch 83/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 84/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 85/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0025
# Epoch 86/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0025
# Epoch 87/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0025
# Epoch 88/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0025
# Epoch 89/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 90/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0024
# Epoch 91/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0024
# Epoch 92/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0025
# Epoch 93/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0025
# Epoch 94/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 95/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0025
# Epoch 96/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0024
# Epoch 97/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 98/120
# 37/37 [==============================] - 5s 144ms/step - loss: 0.0024
# Epoch 99/120
# 37/37 [==============================] - 5s 140ms/step - loss: 0.0024
# Epoch 100/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0023
# Epoch 101/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0025
# Epoch 102/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 103/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0024
# Epoch 104/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0024
# Epoch 105/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0024
# Epoch 106/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0024
# Epoch 107/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0024
# Epoch 108/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0024
# Epoch 109/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0024
# Epoch 110/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0024
# Epoch 111/120
# 37/37 [==============================] - 5s 128ms/step - loss: 0.0024
# Epoch 112/120
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0024
# Epoch 113/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 114/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0026
# Epoch 115/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# Epoch 116/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0023
# Epoch 117/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0023
# Epoch 118/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 119/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0024
# Epoch 120/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0025
# 50/50 [==============================] - 3s 21ms/step
# Epoch 1/120
# 37/37 [==============================] - 21s 130ms/step - loss: 0.0088
# Epoch 2/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0044
# Epoch 3/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0039
# Epoch 4/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0037
# Epoch 5/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0038
# Epoch 6/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0035
# Epoch 7/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0035
# Epoch 8/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0034
# Epoch 9/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034
# Epoch 10/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0032
# Epoch 11/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0031
# Epoch 12/120
# 37/37 [==============================] - 6s 148ms/step - loss: 0.0032
# Epoch 13/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0031
# Epoch 14/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0033
# Epoch 15/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0032
# Epoch 16/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0031
# Epoch 17/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0029
# Epoch 18/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0029
# Epoch 19/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0030
# Epoch 20/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0030
# Epoch 21/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0030
# Epoch 22/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0030
# Epoch 23/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 24/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0029
# Epoch 25/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 26/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0029
# Epoch 27/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0030
# Epoch 28/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0030
# Epoch 29/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0030
# Epoch 30/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0033
# Epoch 31/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0028
# Epoch 32/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0028
# Epoch 33/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0029
# Epoch 34/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028
# Epoch 35/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0029
# Epoch 36/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0029
# Epoch 37/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028
# Epoch 38/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 39/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0027
# Epoch 40/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0028
# Epoch 41/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 42/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0028
# Epoch 43/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0028
# Epoch 44/120
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0028
# Epoch 45/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0029
# Epoch 46/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0028
# Epoch 47/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 48/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0027
# Epoch 49/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 50/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 51/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0028
# Epoch 52/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 53/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 54/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 55/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0027
# Epoch 56/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0028
# Epoch 57/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0027
# Epoch 58/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 59/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0027
# Epoch 60/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0026
# Epoch 61/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 62/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0027
# Epoch 63/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 64/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0027
# Epoch 65/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0026
# Epoch 66/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0027
# Epoch 67/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 68/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0026
# Epoch 69/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0026
# Epoch 70/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0027
# Epoch 71/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0026
# Epoch 72/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0026
# Epoch 74/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 75/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0026
# Epoch 76/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0026
# Epoch 77/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0026
# Epoch 78/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0025
# Epoch 79/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0040
# Epoch 80/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0029
# Epoch 81/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 82/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0027
# Epoch 83/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 84/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0027
# Epoch 85/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 86/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 87/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0027
# Epoch 88/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 89/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0027
# Epoch 90/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 91/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0027
# Epoch 92/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0026
# Epoch 93/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 94/120
# 37/37 [==============================] - 5s 146ms/step - loss: 0.0026
# Epoch 95/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0025
# Epoch 96/120
# ...
# 37/37 [==============================] - 5s 141ms/step - loss: 0.0026
# Epoch 57/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 58/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 59/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0026
# Epoch 60/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0025
# Epoch 61/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 62/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0027
# Epoch 63/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 64/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 65/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0026
# Epoch 66/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0027
# Epoch 67/120
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0025
# Epoch 68/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0027
# Epoch 69/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 70/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0026
# Epoch 71/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0025
# Epoch 72/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0027
# Epoch 74/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 75/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 76/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0026
# Epoch 77/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0025
# Epoch 78/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0026
# Epoch 79/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0032
# Epoch 80/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 81/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0025
# Epoch 82/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0026
# Epoch 83/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0026
# Epoch 84/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0025
# Epoch 85/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0025
# Epoch 86/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0025
# Epoch 87/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0025
# Epoch 88/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# Epoch 89/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0025
# Epoch 90/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 91/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0024
# Epoch 92/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 93/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0025
# Epoch 94/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0024
# Epoch 95/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0024
# Epoch 96/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0024
# Epoch 97/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0025
# Epoch 98/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0026
# Epoch 99/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0024
# Epoch 100/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0025
# Epoch 101/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0041
# Epoch 102/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0028
# Epoch 103/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0028
# Epoch 104/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0028
# Epoch 105/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 106/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0025
# Epoch 107/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 108/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 109/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 110/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 111/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0024
# Epoch 112/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 113/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0024
# Epoch 114/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 115/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0024
# Epoch 116/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 117/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0023
# Epoch 118/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0023
# Epoch 119/120
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0024
# Epoch 120/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0023
# 50/50 [==============================] - 3s 22ms/step
# Epoch 1/120
# 37/37 [==============================] - 21s 140ms/step - loss: 0.0095
# Epoch 2/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0044
# Epoch 3/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0042
# Epoch 4/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0037
# Epoch 5/120
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0039
# Epoch 6/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0037
# Epoch 7/120
# 37/37 [==============================] - 6s 159ms/step - loss: 0.0038
# Epoch 8/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0034
# Epoch 9/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0034
# Epoch 10/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0033
# Epoch 11/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0032
# Epoch 12/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0031
# Epoch 13/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0031
# Epoch 14/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0031
# Epoch 15/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0032
# Epoch 16/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0031
# Epoch 17/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0030
# Epoch 18/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 19/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0029
# Epoch 20/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0028
# Epoch 21/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0030
# Epoch 22/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0029
# Epoch 23/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0029
# Epoch 24/120
# 37/37 [==============================] - 5s 127ms/step - loss: 0.0030
# Epoch 25/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0030
# Epoch 26/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0031
# Epoch 27/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0029
# Epoch 28/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028
# Epoch 29/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0029
# Epoch 30/120
# 37/37 [==============================] - 6s 154ms/step - loss: 0.0029
# Epoch 31/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0030
# Epoch 32/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0029
# Epoch 33/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0028
# Epoch 34/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0028
# Epoch 35/120
# 37/37 [==============================] - 5s 143ms/step - loss: 0.0028
# Epoch 36/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0027
# Epoch 37/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0027
# Epoch 38/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0028
# Epoch 39/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0028
# Epoch 40/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 41/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0027
# Epoch 42/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0028
# Epoch 43/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 44/120
# 37/37 [==============================] - 7s 185ms/step - loss: 0.0028
# Epoch 45/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 46/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0026
# Epoch 47/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0028
# Epoch 48/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0028
# Epoch 49/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0027
# Epoch 50/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0027
# Epoch 51/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 52/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 53/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028
# Epoch 54/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0028
# Epoch 55/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0029
# Epoch 56/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0026
# Epoch 57/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0028
# Epoch 58/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0027
# Epoch 59/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 60/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0027
# Epoch 61/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 62/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0026
# Epoch 63/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0026
# Epoch 64/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0026
# Epoch 65/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0027
# Epoch 66/120
# 37/37 [==============================] - 5s 149ms/step - loss: 0.0026
# Epoch 67/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0026
# Epoch 68/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 69/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0027
# Epoch 70/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0026
# Epoch 71/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0026
# Epoch 72/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0026
# Epoch 73/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0027
# Epoch 74/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0027
# Epoch 75/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0027
# Epoch 76/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 77/120
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0026
# Epoch 78/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0026
# Epoch 79/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0025
# Epoch 80/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 81/120
# 37/37 [==============================] - 5s 138ms/step - loss: 0.0025
# Epoch 82/120
# 37/37 [==============================] - 6s 153ms/step - loss: 0.0026
# Epoch 83/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0025
# Epoch 84/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0025
# Epoch 85/120
# 37/37 [==============================] - 6s 158ms/step - loss: 0.0025
# Epoch 86/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0025
# Epoch 87/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0026
# Epoch 88/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0025
# Epoch 89/120
# 37/37 [==============================] - 7s 182ms/step - loss: 0.0027
# Epoch 90/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0025
# Epoch 91/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0024
# Epoch 92/120
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0025
# Epoch 93/120
# 37/37 [==============================] - 5s 136ms/step - loss: 0.0026
# Epoch 94/120
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0024
# Epoch 95/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0025
# Epoch 96/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0025
# Epoch 97/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0028
# Epoch 98/120
# 37/37 [==============================] - 6s 162ms/step - loss: 0.0027
# Epoch 99/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 100/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0024
# Epoch 101/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0025
# Epoch 102/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0026
# Epoch 103/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0024
# Epoch 104/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0024
# Epoch 105/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0023
# Epoch 106/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0024
# Epoch 107/120
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0025
# Epoch 108/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 109/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0024
# Epoch 110/120
# 37/37 [==============================] - 6s 163ms/step - loss: 0.0026
# Epoch 111/120
# 37/37 [==============================] - 5s 130ms/step - loss: 0.0026
# Epoch 112/120
# 37/37 [==============================] - 6s 160ms/step - loss: 0.0024
# Epoch 113/120
# 37/37 [==============================] - 5s 133ms/step - loss: 0.0024
# Epoch 114/120
# 37/37 [==============================] - 6s 155ms/step - loss: 0.0023
# Epoch 115/120
# 37/37 [==============================] - 5s 137ms/step - loss: 0.0024
# Epoch 116/120
# 37/37 [==============================] - 5s 139ms/step - loss: 0.0024
# Epoch 117/120
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0024
# Epoch 118/120
# 37/37 [==============================] - 5s 131ms/step - loss: 0.0024
# Epoch 119/120
# 37/37 [==============================] - 6s 157ms/step - loss: 0.0023
# Epoch 120/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0024
# 50/50 [==============================] - 3s 32ms/step
# Epoch 1/120
# 37/37 [==============================] - 23s 187ms/step - loss: 0.0089
# Epoch 2/120
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0043
# Epoch 3/120
# 37/37 [==============================] - 5s 142ms/step - loss: 0.0041
# Epoch 4/120
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0038
# Epoch 5/120
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0035
# Epoch 6/120
# 21/37 [================>.............] - ETA: 2s - loss: 0.0033
# KeyboardInterrupt

# %%
print(loss)
# Out:
# [0.0682440990779359, 0.06281838027578392, 0.06996728012349787, 0.0634803157577159, 0.056642341422072966, 0.05975145624533488, 0.06948958757399842, 0.06881394836553294]

# %%
print(min(loss))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(loss)
