# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPANJAN001/Forecasting-Solar-Energy/blob/master/optimizer6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install Boruta
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import concatenate
from keras import Model
from keras.layers import Input
from keras.layers import Bidirectional
from keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model
from keras.layers import Input
from sklearn.decomposition import PCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 KB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.7.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.8/dist-packages (from Boruta) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.1.0)
# Installing collected packages: Boruta
# Successfully installed Boruta-0.3

# %%
def lstm_data_transform(x_data, y_data, num_steps):
    """ Changes data to the format for LSTM training 
for sliding window approach """
    # Prepare the list for the transformed data
    X, y = list(), list()
    # Loop of the entire data set
    for i in range(x_data.shape[0]):
        # compute a new (sliding window) index
        end_ix = i + num_steps
        # if index is larger than the size of the dataset, we stop
        if end_ix >= x_data.shape[0]:
            break
        # Get a sequence of data for x
        seq_X = x_data[i:end_ix]
        # Get only the last element of the sequency for y
        seq_y = y_data[end_ix]
        # Append the list with sequencies
        X.append(seq_X)
        y.append(seq_y)
    # Make final arrays
    x_array = np.array(X)
    y_array = np.array(y)
    return x_array, y_array

# %%
df=pd.read_excel("/content/pv_04.xlsx")
weather_input1=df.drop('power_normed',axis=1)
weather_input=weather_input1.drop('time_idx',axis=1)
solpow=df['power_normed']

# %%
rfc = RandomForestRegressor(random_state=1, n_estimators=1000, max_depth=10)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(weather_input), np.array(solpow))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	49
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	9
# Tentative: 	8
# Rejected: 	32
# Iteration: 	9 / 100
# Confirmed: 	9
# Tentative: 	8
# Rejected: 	32
# Iteration: 	10 / 100
# Confirmed: 	9
# Tentative: 	8
# Rejected: 	32
# Iteration: 	11 / 100
# Confirmed: 	9
# Tentative: 	8
# Rejected: 	32
# Iteration: 	12 / 100
# Confirmed: 	12
# Tentative: 	5
# Rejected: 	32
# Iteration: 	13 / 100
# Confirmed: 	12
# Tentative: 	5
# Rejected: 	32
# Iteration: 	14 / 100
# Confirmed: 	12
# Tentative: 	5
# Rejected: 	32
# Iteration: 	15 / 100
# Confirmed: 	12
# Tentative: 	5
# Rejected: 	32
# Iteration: 	16 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	17 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	18 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	19 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	20 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	21 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	22 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	23 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	24 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	25 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	26 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	27 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	28 / 100
# Confirmed: 	13
# Tentative: 	4
# Rejected: 	32
# Iteration: 	29 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	30 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	31 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	32 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	33 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	34 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	35 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	36 / 100
# Confirmed: 	14
# Tentative: 	3
# Rejected: 	32
# Iteration: 	37 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	38 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	39 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	40 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	41 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	42 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	43 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	44 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	45 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	32
# Iteration: 	46 / 100
# Confirmed: 	16
# Tentative: 	0
# Rejected: 	33
#
#
# BorutaPy finished running.
#
# Iteration: 	47 / 100
# Confirmed: 	16
# Tentative: 	0
# Rejected: 	33
# BorutaPy(estimator=RandomForestRegressor(max_depth=10, n_estimators=58,
#                                          random_state=RandomState(MT19937) at 0x7F5A29AD8640),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x7F5A29AD8640, verbose=2)

# %%
X_important_train = boruta_selector.transform(np.array(weather_input))
num_steps = 3
# training set
(x_transformed_train,
 y_transformed_train) = lstm_data_transform(X_important_train,solpow , num_steps=num_steps)
assert x_transformed_train.shape[0] == y_transformed_train.shape[0]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_transformed_train,y_transformed_train,test_size=0.33, random_state=42,shuffle=False)
#X_train_,X_val,y_train_,y_val=train_test_split(X_train,y_train,test_size=0.2, random_state=42,shuffle=False)
inputs1 = Input(shape=(X_train.shape[1],X_train.shape[2]))

# %%
inputs1
# Out:
# <KerasTensor: shape=(None, 3, 16) dtype=float32 (created by layer 'input_1')>

# %%
from keras import optimizers

# %%
from keras.optimizers import Adam
import numpy as np

class SPANDAN(Adam):
    def __init__(self, num_restarts=20, num_steps=100, lr=0.003, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + 2*distance for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters*s
            params_2 = [b - 2*distance for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
class SPANDAN1(Adam):
    def __init__(self, num_restarts=20, num_steps=100, lr=0.003, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
          
            
            # Adding noise to the best parameters
            params_1 = [b + 2*distance for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters*s
            params_2 = [b - 2*distance for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
from keras.optimizers import Adam
import numpy as np

class RandomRestartAdam(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(RandomRestartAdam, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters
            params_2 = [b - (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
from keras.layers import Bidirectional

# %%
def define_model():



  '''fe1_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = Bidirectional(LSTM(24, activation='relu',return_sequences = True))(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=Bidirectional(LSTM(30, activation='relu'))(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)'''



  fe2_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = Bidirectional(LSTM(60, activation='relu',return_sequences = True))(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=Bidirectional(LSTM(4, activation='relu'))(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =Bidirectional(LSTM(104, activation='relu',return_sequences = True))(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = Bidirectional(LSTM(96, activation='relu',return_sequences = True))(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=Bidirectional(LSTM(8, activation='relu'))(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  output = layers.average([ out3_1, out2_1])
  #merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  #output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer =RandomRestartAdam(),loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 75,validation_split=0.2,batch_size =64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/75
# 51/51 [==============================] - 24s 133ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 2/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 3/75
# 51/51 [==============================] - 6s 110ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 4/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 5/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 6/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 7/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 8/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 9/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 10/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 11/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 12/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 13/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 14/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 15/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 16/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 17/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 18/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 19/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 20/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 21/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 22/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 23/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 24/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 25/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 26/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 27/75
# 51/51 [==============================] - 4s 81ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 28/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 29/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 30/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 31/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 32/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 33/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 34/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 35/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 36/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 37/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 38/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 39/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 40/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 41/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 42/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 43/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 44/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 45/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 46/75
# 51/51 [==============================] - 6s 111ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 47/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 48/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 49/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 50/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 51/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 52/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 53/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 54/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 55/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 56/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 57/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 58/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 59/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 60/75
# 51/51 [==============================] - 6s 124ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 61/75
# 51/51 [==============================] - 5s 102ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 62/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 63/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 64/75
# 51/51 [==============================] - 4s 84ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 65/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 66/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 67/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 68/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 69/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 70/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 71/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 72/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 73/75
# 51/51 [==============================] - 4s 82ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 74/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 75/75
# 51/51 [==============================] - 4s 83ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0014 - val_mse: 0.0014
# 63/63 [==============================] - 3s 14ms/step
# 0.05706692757115133

# %%
def define_model():


  # firs
  fe1_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe1_1 = Dropout(0.5)(fe1_0)
  fe1_2 = Bidirectional(LSTM(24, activation='relu',return_sequences = True))(fe1_1)
  fe1_3= Dropout(0.2)(fe1_2)
  fe1_4=Bidirectional(LSTM(30, activation='relu'))(fe1_3)
  out1_1=Dense(1, activation='relu')(fe1_4)



  fe2_0 = Bidirectional(LSTM(208, activation='relu',return_sequences = True))(inputs1)
  fe2_1 = Dropout(0.6)(fe2_0)
  fe2_2 = Bidirectional(LSTM(60, activation='relu',return_sequences = True))(fe2_1)
  fe2_3= Dropout(0.5)(fe2_2)
  fe2_4=Bidirectional(LSTM(4, activation='relu'))(fe2_3)
  out2_1=Dense(1, activation='relu')(fe2_4)

  fe3_0 =Bidirectional(LSTM(104, activation='relu',return_sequences = True))(inputs1)
  fe3_1 = Dropout(0.6)(fe3_0)
  fe3_2 = Bidirectional(LSTM(96, activation='relu',return_sequences = True))(fe3_1)
  fe3_3= Dropout(0.5)(fe3_2)
  fe3_4=Bidirectional(LSTM(8, activation='relu'))(fe3_3)#16
  out3_1=Dense(1, activation='relu')(fe3_4)
 
 

  #output = layers.average([ out1_1, out2_1, out3_1])
  merged3 = concatenate([out1_1,out2_1,out3_1], name='concat3')
  output = Dense(1, activation='relu')( merged3)
  

  model = Model(inputs=[inputs1], outputs=[output])
  model.compile(optimizer=SPANDAN(),loss='mean_squared_error',metrics=['mse'])
 
  return model
mdl=define_model()
history=mdl.fit(X_train, y_train, epochs = 80,validation_split=0.2,batch_size =128)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/80
# 26/26 [==============================] - ETA: 0s - loss: 0.0218 - mse: 0.0218
# KeyboardInterrupt

# %%
from keras.optimizers import Adam
from keras import backend as K
import numpy as np

class RandomRestartAdam(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(RandomRestartAdam, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None

    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            if self.noise_std != 0:
                noise = K.random_normal(shape=K.shape(self.best_weights), mean=0., stddev=self.noise_std)
                self.best_weights = [w + n for w, n in zip(self.best_weights, noise)]
            self.model.set_weights(self.best_weights)

# %%
class SPANDAN1(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.1, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN1, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters
            params_2 = [b - (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
class SPANDAN2(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.01, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN2, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters
            params_2 = [b - (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
class SPANDAN3(Adam):
    def __init__(self, num_restarts=10, num_steps=100, lr=0.001, beta_1=0.9, beta_2=0.999,
                 epsilon=1e-8, decay=0., amsgrad=False, noise_std=0.1, **kwargs):
        super(SPANDAN3, self).__init__(lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
        self.num_restarts = num_restarts
        self.num_steps = num_steps
        self.noise_std = noise_std
        self.best_loss = np.inf
        self.best_weights = None
        self.initial_weights = None
    
    def get_weights(self):
        return self.best_weights

    def set_weights(self, weights):
        self.best_weights = weights
        self.initial_weights = weights

    def on_train_begin(self, logs=None):
        self.best_loss = np.inf
        self.initial_weights = self.model.get_weights()

    def on_batch_end(self, batch, logs=None):
        current_loss = logs.get('loss')
        if current_loss < self.best_loss:
            self.best_loss = current_loss
            self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.num_restarts == 0 and epoch > 0:
            for _ in range(self.num_steps):
                self.model.fit(self.model.train_on_batch, epochs=1, verbose=0)
                current_loss = logs.get('loss')
                if current_loss < self.best_loss:
                    self.best_loss = current_loss
                    self.best_weights = self.model.get_weights()
            # calculate distance 
            distance = [np.linalg.norm(b - i) for b, i in zip(self.best_weights, self.initial_weights)]
            distance = sum(distance)/len(distance)
            
            # Adding noise to the best parameters
            params_1 = [b + (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_1)
            self.initial_weights = params_1

            # subtract noise to the best parameters
            params_2 = [b - (distance*self.noise_std) for b in self.best_weights]
            self.model.set_weights(params_2)
            self.initial_weights = params_2

# %%
from keras.optimizers import Adam
from keras.layers import Bidirectional, LSTM, Dense
from keras.models import Sequential

# Define the model
model = Sequential()
model.add(Bidirectional(LSTM(64, return_sequences=True), input_shape=(3, 16)))
model.add(Bidirectional(LSTM(32)))
model.add(Dense(1, activation='relu'))

# Define optimizers for different layers
lstm_1_optimizer = SPANDAN1()
lstm_2_optimizer = SPANDAN2()
dense_optimizer = SPANDAN3()

# Compile the model with the custom optimizers
model.compile(optimizer=dense_optimizer,loss='mean_squared_error',metrics=['mse'])

# Set the optimizers for the layers
model.layers[0].layer.trainable = True
model.layers[0].layer.optimizer = lstm_1_optimizer
model.layers[1].layer.trainable = True
model.layers[1].layer.optimizer = lstm_2_optimizer

# %%
history=model.fit(X_train, y_train, epochs = 100,validation_split=0.2,batch_size =64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 51/51 [==============================] - 11s 50ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 2/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 3/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 4/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 5/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 6/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 7/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 8/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 9/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 10/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 11/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 12/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 13/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 14/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 15/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 16/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 17/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 18/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 19/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 20/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 21/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 22/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 23/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 24/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 25/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 26/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 27/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 28/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 29/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 30/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 31/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 32/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 33/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 34/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 35/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 36/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 37/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 38/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 39/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 40/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 41/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 42/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 43/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 44/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 45/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 46/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 47/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 48/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 49/100
# 51/51 [==============================] - 1s 23ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 50/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 51/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 52/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 53/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 54/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 55/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 56/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 57/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 58/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 59/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 60/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 61/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 62/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 63/100
# 51/51 [==============================] - 2s 31ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 64/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 65/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 66/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 67/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 68/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 69/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 70/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 71/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 72/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 73/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 74/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 75/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 76/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 77/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 78/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 79/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 80/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 81/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 82/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 83/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 84/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 85/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 86/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 87/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 88/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 89/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 90/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 91/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 92/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 93/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 94/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 95/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 96/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 97/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 98/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 99/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 100/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# 63/63 [==============================] - 1s 15ms/step
# 0.05706692757115133

# %%
lstm_1_optimizer = SPANDAN1()
lstm_2_optimizer = SPANDAN2()
dense_optimizer = SPANDAN3()

# %%
model = Sequential()
model.add(Bidirectional(LSTM(104,activation='relu',return_sequences=True), input_shape=(3, 16)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(32,activation='relu',return_sequences=True)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(8,activation='relu')))
model.add(Dense(1, activation='relu'))
model.compile(optimizer=dense_optimizer,loss='mean_squared_error',metrics=['mse'])
model.layers[0].layer.trainable = True
model.layers[0].layer.optimizer = lstm_1_optimizer
model.layers[2].layer.trainable = True
model.layers[2].layer.optimizer = lstm_2_optimizer
model.layers[4].layer.trainable = True
model.layers[4].layer.optimizer = lstm_2_optimizer

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_47 (Bidirecti  (None, 3, 208)           100672
#  onal)
#
#  dropout_42 (Dropout)        (None, 3, 208)            0
#
#  bidirectional_48 (Bidirecti  (None, 3, 64)            61696
#  onal)
#
#  dropout_43 (Dropout)        (None, 3, 64)             0
#
#  bidirectional_49 (Bidirecti  (None, 16)               4672
#  onal)
#
#  dense_24 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 167,057
# Trainable params: 167,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train, y_train, epochs =100,validation_split=0.2,batch_size =64)
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
y=mdl.predict(X_test)
plt.scatter(y,y_test)
plt.show()
df = pd.DataFrame()
df['time']=[i for i in range(len(y))]
df['Actual']=y_test
df['Predicted']=y
plt.plot(df['time'],df['Actual'])
plt.plot(df['time'],df['Predicted'])
plt.show()
print(np.sqrt(mean_squared_error(y,y_test)))
# Out:
# Epoch 1/100
# 51/51 [==============================] - 10s 45ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 2/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 3/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 4/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 5/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 6/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 7/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 8/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 9/100
# 51/51 [==============================] - 1s 24ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 10/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 11/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 12/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 13/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 14/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 15/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 16/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 17/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 18/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 19/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 20/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 21/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 22/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 23/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 24/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 25/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 26/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 27/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 28/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 29/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 30/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 31/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 32/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 33/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 34/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 35/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 36/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 37/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 38/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 39/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 40/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 41/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 42/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 43/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 44/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 45/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 46/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 47/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 48/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 49/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 50/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 51/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 52/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 53/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 54/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 55/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 56/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 57/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 58/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 59/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 60/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 61/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 62/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 63/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 64/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 65/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 66/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 67/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 68/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 69/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 70/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 71/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 72/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 73/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 74/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 75/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 76/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 77/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 78/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 79/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 80/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 81/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 82/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 83/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 84/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 85/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 86/100
# 51/51 [==============================] - 2s 49ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 87/100
# 51/51 [==============================] - 2s 32ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 88/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 89/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 90/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 91/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 92/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 93/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 94/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 95/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 96/100
# 51/51 [==============================] - 1s 27ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 97/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 98/100
# 51/51 [==============================] - 1s 25ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 99/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 100/100
# 51/51 [==============================] - 1s 26ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0011 - val_mse: 0.0011
# 63/63 [==============================] - 1s 14ms/step
# 0.05706692757115133
